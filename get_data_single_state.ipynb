# %% [markdown]
# # create pandas DataFrames to analyze
#
# ### this is a sample Notebook that shows how to retrieve data from the COVID api and create initial dataframes for analysis
#
# #### the Notebook contains
#
# 1) query used to get CMU data from https://cmu-delphi.github.io/delphi-epidata/api/covidcast.html
#
#
# the **Target** is to get a pandas DataFrame for a each state with the following columns
#
# *********************************************************************
#
# Away from Home 6hr+ (SG),
#
# Away from Home 3-6hr (SG),
#
# Search Trends (Google),
#
# Doctor Visits,
#
# Symptoms (FB),
#
# Symptoms in Community (FB),
#
# Combined,
#
# COVID-19 Antigen Tests (Quidel),
#
# Hospital Admissions,
#
# Cases,
#
# Deaths
#
# ***********************************************************************

# %%
import covidcast
import pandas as pd 
from datetime import date
import os

# %% [markdown]
# *******************************************************************
#
# The signals and query examples are explained in https://cmu-delphi.github.io/delphi-epidata/api/covidcast.html
#
# **************************************************************************

# %%
state = "oh"
start_date = date(2020, 3, 4)
end_date = date(2020, 10, 6)

# %% [markdown]
# we will define 11 variables {c_i}, each one will contain the output of each of the 11 signals:
#
# 1- Away from Home 6hr+ (SG),
#
# 2- Away from Home 3-6hr (SG),
#
# 3- Search Trends (Google),
#
# 4- Doctor Visits,
#
# 5- Symptoms (FB),
#
# 6- Symptoms in Community (FB),
#
# 7- Combined,
#
# 8- COVID-19 Antigen Tests (Quidel),
#
# 9- Hospital Admissions,
#
# 10- Cases,
#
# 11- Deaths
#
# This is an arbitrary preliminar selection.

# %%
c1 = covidcast.signal("safegraph","full_time_work_prop", 
                      start_date, end_date, geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201003: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201004: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201005: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c1.head()
# Out:
#   geo_value               signal time_value direction      issue  lag  \
# 0        oh  full_time_work_prop 2020-03-04         0 2020-06-23  111
# 0        oh  full_time_work_prop 2020-03-05         1 2020-06-23  110
# 0        oh  full_time_work_prop 2020-03-06         1 2020-06-23  109
# 0        oh  full_time_work_prop 2020-03-07         0 2020-06-23  108
# 0        oh  full_time_work_prop 2020-03-08        -1 2020-06-23  107
#
#       value    stderr  sample_size geo_type data_source
# 0  0.094011  0.000553         9220    state   safegraph
# 0  0.090383  0.000537         9225    state   safegraph
# 0  0.077313  0.000491         9225    state   safegraph
# 0  0.028089  0.000220         9222    state   safegraph
# 0  0.024239  0.000206         9225    state   safegraph

# %%
c2 = covidcast.signal("safegraph","part_time_work_prop", 
                      start_date, end_date,geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201003: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201004: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201005: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c2.head()
# Out:
#   geo_value               signal time_value direction      issue  lag  \
# 0        oh  part_time_work_prop 2020-03-04         0 2020-06-23  111
# 0        oh  part_time_work_prop 2020-03-05         1 2020-06-23  110
# 0        oh  part_time_work_prop 2020-03-06         1 2020-06-23  109
# 0        oh  part_time_work_prop 2020-03-07         0 2020-06-23  108
# 0        oh  part_time_work_prop 2020-03-08        -1 2020-06-23  107
#
#       value    stderr  sample_size geo_type data_source
# 0  0.110742  0.000582         9220    state   safegraph
# 0  0.113740  0.000577         9225    state   safegraph
# 0  0.101803  0.000546         9225    state   safegraph
# 0  0.062543  0.000365         9222    state   safegraph
# 0  0.054198  0.000358         9225    state   safegraph

# %%
c3 = covidcast.signal("ght","smoothed_search", 
                      start_date, end_date,geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200711: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200817: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200821: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200919: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201003: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201004: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201005: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c3.head()
# Out:
#   geo_value           signal time_value direction      issue  lag      value  \
# 0        oh  smoothed_search 2020-03-04         0 2020-05-06   63   8.370803
# 0        oh  smoothed_search 2020-03-05         0 2020-05-06   62  10.089689
# 0        oh  smoothed_search 2020-03-06         0 2020-05-06   61   9.602428
# 0        oh  smoothed_search 2020-03-07         0 2020-05-06   60  10.705053
# 0        oh  smoothed_search 2020-03-08         0 2020-05-06   59  10.503644
#
#   stderr sample_size geo_type data_source
# 0   None        None    state         ght
# 0   None        None    state         ght
# 0   None        None    state         ght
# 0   None        None    state         ght
# 0   None        None    state         ght

# %%
c4 = covidcast.signal("doctor-visits","smoothed_adj_cli", 
                      start_date, end_date, geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201004: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201005: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c4.head()
# Out:
#   geo_value            signal time_value direction      issue  lag     value  \
# 0        oh  smoothed_adj_cli 2020-03-04         0 2020-06-09   97  0.124477
# 0        oh  smoothed_adj_cli 2020-03-05         0 2020-06-09   96  0.125593
# 0        oh  smoothed_adj_cli 2020-03-06         0 2020-06-09   95  0.126562
# 0        oh  smoothed_adj_cli 2020-03-07         0 2020-06-09   94  0.126157
# 0        oh  smoothed_adj_cli 2020-03-08         0 2020-06-09   93  0.125763
#
#   stderr sample_size geo_type    data_source
# 0   None        None    state  doctor-visits
# 0   None        None    state  doctor-visits
# 0   None        None    state  doctor-visits
# 0   None        None    state  doctor-visits
# 0   None        None    state  doctor-visits

# %%
c5 = covidcast.signal("fb-survey","smoothed_cli", 
                      start_date,end_date,geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200304: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200305: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200306: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200307: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200308: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200309: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200310: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200311: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200312: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200313: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200314: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200315: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200316: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200317: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200318: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200319: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200320: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200321: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200322: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200323: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200324: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200325: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200326: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200327: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200328: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200329: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200330: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200331: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200401: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200402: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200403: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200404: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200405: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c5.head()
# Out:
#   geo_value        signal time_value direction      issue  lag     value  \
# 0        oh  smoothed_cli 2020-04-06      None 2020-09-03  150  0.780034
# 0        oh  smoothed_cli 2020-04-07      None 2020-09-03  149  0.867632
# 0        oh  smoothed_cli 2020-04-08      None 2020-09-03  148  0.820641
# 0        oh  smoothed_cli 2020-04-09      None 2020-09-03  147  0.800846
# 0        oh  smoothed_cli 2020-04-10      None 2020-09-03  146  0.784195
#
#      stderr  sample_size geo_type data_source
# 0  0.139454    3158.9990    state   fb-survey
# 0  0.073575   11915.9981    state   fb-survey
# 0  0.055031   19818.0017    state   fb-survey
# 0  0.046752   26307.0080    state   fb-survey
# 0  0.043720   29487.0080    state   fb-survey

# %%
c6 = covidcast.signal("fb-survey","smoothed_hh_cmnty_cli", 
                      start_date, end_date,geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200304: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200305: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200306: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200307: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200308: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200309: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200310: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200311: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200312: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200313: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200314: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200315: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200316: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200317: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200318: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200319: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200320: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200321: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200322: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200323: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200324: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200325: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200326: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200327: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200328: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200329: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200330: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200331: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200401: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200402: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200403: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200404: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200405: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200406: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200407: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200408: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200409: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200410: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200411: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200412: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200413: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200414: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c6.head()
# Out:
#   geo_value                 signal time_value direction      issue  lag  \
# 0        oh  smoothed_hh_cmnty_cli 2020-04-15      None 2020-09-03  141
# 0        oh  smoothed_hh_cmnty_cli 2020-04-16      None 2020-09-03  140
# 0        oh  smoothed_hh_cmnty_cli 2020-04-17      None 2020-09-03  139
# 0        oh  smoothed_hh_cmnty_cli 2020-04-18      None 2020-09-03  138
# 0        oh  smoothed_hh_cmnty_cli 2020-04-19      None 2020-09-03  137
#
#        value    stderr  sample_size geo_type data_source
# 0  22.523592  1.171739    1271.0005    state   fb-survey
# 0  21.840372  0.655649    3971.0019    state   fb-survey
# 0  22.074185  0.547380    5741.0019    state   fb-survey
# 0  21.801290  0.473999    7588.0031    state   fb-survey
# 0  21.704044  0.418061    9722.9984    state   fb-survey

# %%
c7 = covidcast.signal("indicator-combination","nmf_day_doc_fbc_fbs_ght", 
                      start_date, end_date,geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200304: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200305: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200306: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200307: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200308: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200309: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200310: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200311: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200312: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200313: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200314: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200315: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200316: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200317: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200318: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200319: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200320: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200321: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200322: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200323: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200324: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200325: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200326: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200327: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200328: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200329: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200330: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200331: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200401: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200402: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200403: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200404: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200405: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200406: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200407: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200408: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200409: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200410: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200411: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200412: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200413: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200414: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c7.head()
# Out:
#   geo_value                   signal time_value direction      issue  lag  \
# 0        oh  nmf_day_doc_fbc_fbs_ght 2020-04-15      None 2020-07-15   91
# 0        oh  nmf_day_doc_fbc_fbs_ght 2020-04-16      None 2020-07-16   91
# 0        oh  nmf_day_doc_fbc_fbs_ght 2020-04-17        -1 2020-07-16   90
# 0        oh  nmf_day_doc_fbc_fbs_ght 2020-04-18      None 2020-07-18   91
# 0        oh  nmf_day_doc_fbc_fbs_ght 2020-04-19      None 2020-07-18   90
#
#       value    stderr sample_size geo_type            data_source
# 0  1.030874  0.034099        None    state  indicator-combination
# 0  1.002329  0.035750        None    state  indicator-combination
# 0  0.970479  0.040600        None    state  indicator-combination
# 0  0.958182  0.033116        None    state  indicator-combination
# 0  0.915411  0.033441        None    state  indicator-combination

# %%
c8 = covidcast.signal("quidel","covid_ag_smoothed_pct_positive", 
                      start_date, end_date,geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200304: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200305: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200306: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200307: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200308: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200309: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200310: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200311: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200312: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200313: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200314: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200315: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200316: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200317: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200318: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200319: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200320: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200321: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200322: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200323: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200324: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200325: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200326: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200327: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200328: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200329: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200330: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200331: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200401: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200402: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200403: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200404: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200405: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200406: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200407: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200408: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200409: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200410: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200411: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200412: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200413: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200414: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200415: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200416: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200417: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200418: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200419: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200420: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200421: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200422: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200423: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200424: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200425: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200426: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200427: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200428: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200429: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200430: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200501: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200502: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200503: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200504: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200505: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200506: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200507: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200508: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200509: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200510: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200511: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200512: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200513: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200514: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200515: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200516: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200517: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200518: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200519: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200520: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200521: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200522: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200523: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200524: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200525: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200526: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200527: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200528: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200529: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200530: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200531: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200601: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200602: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200603: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200604: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200605: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200606: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200607: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200608: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200609: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200610: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200611: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200612: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200613: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200614: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200615: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201002: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201003: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201004: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201005: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c8.head()
# Out:
#   geo_value                          signal time_value direction      issue  \
# 0        oh  covid_ag_smoothed_pct_positive 2020-06-16      None 2020-08-20
# 0        oh  covid_ag_smoothed_pct_positive 2020-06-17      None 2020-08-20
# 0        oh  covid_ag_smoothed_pct_positive 2020-06-18      None 2020-08-20
# 0        oh  covid_ag_smoothed_pct_positive 2020-06-19      None 2020-08-20
# 0        oh  covid_ag_smoothed_pct_positive 2020-06-20      None 2020-08-20
#
#    lag      value    stderr  sample_size geo_type data_source
# 0   65  13.636364  2.586774          176    state      quidel
# 0   64   9.438776  1.476678          392    state      quidel
# 0   63  11.631206  1.207445          705    state      quidel
# 0   62  11.699164  1.199493          718    state      quidel
# 0   61  11.634349  1.193285          722    state      quidel

# %%
c9 = covidcast.signal("hospital-admissions","smoothed_adj_covid19", 
                      start_date, end_date,geo_type="state", 
                      geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200928: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200929: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20200930: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201001: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201002: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201003: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201004: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201005: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c9.head()
# Out:
#   geo_value                signal time_value direction      issue  lag  \
# 0        oh  smoothed_adj_covid19 2020-03-04         0 2020-06-30  118
# 0        oh  smoothed_adj_covid19 2020-03-05         0 2020-06-30  117
# 0        oh  smoothed_adj_covid19 2020-03-06         0 2020-06-30  116
# 0        oh  smoothed_adj_covid19 2020-03-07         0 2020-06-30  115
# 0        oh  smoothed_adj_covid19 2020-03-08         0 2020-06-30  114
#
#       value stderr sample_size geo_type          data_source
# 0  0.023816   None        None    state  hospital-admissions
# 0  0.032358   None        None    state  hospital-admissions
# 0  0.031611   None        None    state  hospital-admissions
# 0  0.031418   None        None    state  hospital-admissions
# 0  0.032832   None        None    state  hospital-admissions

# %%
c10 = covidcast.signal("indicator-combination","confirmed_7dav_incidence_num", 
                       start_date, end_date,geo_type="state", 
                       geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c10.head()
# Out:
#   geo_value                        signal time_value direction      issue  \
# 0        oh  confirmed_7dav_incidence_num 2020-03-04         0 2020-07-10
# 0        oh  confirmed_7dav_incidence_num 2020-03-05         0 2020-07-10
# 0        oh  confirmed_7dav_incidence_num 2020-03-06         0 2020-07-10
# 0        oh  confirmed_7dav_incidence_num 2020-03-07         0 2020-07-10
# 0        oh  confirmed_7dav_incidence_num 2020-03-08         0 2020-07-10
#
#    lag  value stderr sample_size geo_type            data_source
# 0  128    0.0   None        None    state  indicator-combination
# 0  127    0.0   None        None    state  indicator-combination
# 0  126    0.0   None        None    state  indicator-combination
# 0  125    0.0   None        None    state  indicator-combination
# 0  124    0.0   None        None    state  indicator-combination

# %%
c11 = covidcast.signal("indicator-combination","deaths_7dav_incidence_num",
                       start_date, end_date, geo_type="state", 
                       geo_values=state)
# Out:
# /home/flor/anaconda3/lib/python3.8/site-packages/covidcast/covidcast.py:319: UserWarning: Problem obtaining data on 20201006: no results
#   warnings.warn("Problem obtaining data on {day}: {message}".format(

# %%
c11.head()
# Out:
#   geo_value                     signal time_value direction      issue  lag  \
# 0        oh  deaths_7dav_incidence_num 2020-03-04         0 2020-07-10  128
# 0        oh  deaths_7dav_incidence_num 2020-03-05         0 2020-07-10  127
# 0        oh  deaths_7dav_incidence_num 2020-03-06         0 2020-07-10  126
# 0        oh  deaths_7dav_incidence_num 2020-03-07         0 2020-07-10  125
# 0        oh  deaths_7dav_incidence_num 2020-03-08         0 2020-07-10  124
#
#    value stderr sample_size geo_type            data_source
# 0    0.0   None        None    state  indicator-combination
# 0    0.0   None        None    state  indicator-combination
# 0    0.0   None        None    state  indicator-combination
# 0    0.0   None        None    state  indicator-combination
# 0    0.0   None        None    state  indicator-combination

# %% [markdown]
# ***********************************************************************
# Note: if the state is not specified, the data for a given start date up to a given end date is download. This is just an illustrative example.
#
# We make another arbitrary choice without considering the change logs and the issues in the survey as a first approach, so that we considered only the columns = ['time_value','value', 'stderr', 'sample_size'] for each output
#
# We merge the 11 dataframes we got for each query in order to build a single dataframe for that given state that contains all the features we are interested in. there are some null columns we will drop in smooth.ipynb
#
# The columns ['time_value','value', 'stderr', 'sample_size'] appear in the 11 signals
# *********************************************************************

# %%
cols = ['time_value','value', 'stderr', 'sample_size']
df_outer = pd.merge(c1[cols], c2[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c3[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c4[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c5[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c6[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c7[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c8[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c9[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c10[cols], on='time_value', how='outer')
df_outer = pd.merge(df_outer, c11[cols], on='time_value', how='outer')

# %% [markdown]
# *************************************************************************
# we rename the columns in order to relate them to the variables we will use
# *************************************************************************

# %%
signals = ['full_time_work_prop', 
               'part_time_work_prop',
               'smoothed_search', 
               'smoothed_adj_cli', 
               'smoothed_cli', 
               'smoothed_hh_cmnty_cli', 
              'nmf_day_doc_fbc_fbs_ght', 
               'covid_ag_smoothed_pct_positive', 
              'smoothed_adj_covid19',
               'confirmed_7dav_incidence_num', 
               'deaths_7dav_incidence_num']

# %%
nc = ['time_value']
for i,c in enumerate(signals):
    nc.append(c)
    nc.append('stderr_' + c)
    nc.append('sample_size_' + c)

# %%
nc
# Out:
# ['time_value',
#  'full_time_work_prop',
#  'stderr_full_time_work_prop',
#  'sample_size_full_time_work_prop',
#  'part_time_work_prop',
#  'stderr_part_time_work_prop',
#  'sample_size_part_time_work_prop',
#  'smoothed_search',
#  'stderr_smoothed_search',
#  'sample_size_smoothed_search',
#  'smoothed_adj_cli',
#  'stderr_smoothed_adj_cli',
#  'sample_size_smoothed_adj_cli',
#  'smoothed_cli',
#  'stderr_smoothed_cli',
#  'sample_size_smoothed_cli',
#  'smoothed_hh_cmnty_cli',
#  'stderr_smoothed_hh_cmnty_cli',
#  'sample_size_smoothed_hh_cmnty_cli',
#  'nmf_day_doc_fbc_fbs_ght',
#  'stderr_nmf_day_doc_fbc_fbs_ght',
#  'sample_size_nmf_day_doc_fbc_fbs_ght',
#  'covid_ag_smoothed_pct_positive',
#  'stderr_covid_ag_smoothed_pct_positive',
#  'sample_size_covid_ag_smoothed_pct_positive',
#  'smoothed_adj_covid19',
#  'stderr_smoothed_adj_covid19',
#  'sample_size_smoothed_adj_covid19',
#  'confirmed_7dav_incidence_num',
#  'stderr_confirmed_7dav_incidence_num',
#  'sample_size_confirmed_7dav_incidence_num',
#  'deaths_7dav_incidence_num',
#  'stderr_deaths_7dav_incidence_num',
#  'sample_size_deaths_7dav_incidence_num']

# %%
df_outer.columns = nc

# %% [markdown]
# we have the dataframe we need

# %%
df_outer.head()
# Out:
#   time_value  full_time_work_prop  stderr_full_time_work_prop  \
# 0 2020-03-04             0.094011                    0.000553
# 1 2020-03-05             0.090383                    0.000537
# 2 2020-03-06             0.077313                    0.000491
# 3 2020-03-07             0.028089                    0.000220
# 4 2020-03-08             0.024239                    0.000206
#
#    sample_size_full_time_work_prop  part_time_work_prop  \
# 0                           9220.0             0.110742
# 1                           9225.0             0.113740
# 2                           9225.0             0.101803
# 3                           9222.0             0.062543
# 4                           9225.0             0.054198
#
#    stderr_part_time_work_prop  sample_size_part_time_work_prop  \
# 0                    0.000582                           9220.0
# 1                    0.000577                           9225.0
# 2                    0.000546                           9225.0
# 3                    0.000365                           9222.0
# 4                    0.000358                           9225.0
#
#    smoothed_search stderr_smoothed_search sample_size_smoothed_search  ...  \
# 0         8.370803                   None                        None  ...
# 1        10.089689                   None                        None  ...
# 2         9.602428                   None                        None  ...
# 3        10.705053                   None                        None  ...
# 4        10.503644                   None                        None  ...
#
#    sample_size_covid_ag_smoothed_pct_positive smoothed_adj_covid19  \
# 0                                         NaN             0.023816
# 1                                         NaN             0.032358
# 2                                         NaN             0.031611
# 3                                         NaN             0.031418
# 4                                         NaN             0.032832
#
#   stderr_smoothed_adj_covid19  sample_size_smoothed_adj_covid19  \
# 0                        None                              None
# 1                        None                              None
# 2                        None                              None
# 3                        None                              None
# 4                        None                              None
#
#    confirmed_7dav_incidence_num  stderr_confirmed_7dav_incidence_num  \
# 0                           0.0                                 None
# 1                           0.0                                 None
# 2                           0.0                                 None
# 3                           0.0                                 None
# 4                           0.0                                 None
#
#    sample_size_confirmed_7dav_incidence_num  deaths_7dav_incidence_num  \
# 0                                      None                        0.0
# 1                                      None                        0.0
# 2                                      None                        0.0
# 3                                      None                        0.0
# 4                                      None                        0.0
#
#    stderr_deaths_7dav_incidence_num  sample_size_deaths_7dav_incidence_num
# 0                              None                                   None
# 1                              None                                   None
# 2                              None                                   None
# 3                              None                                   None
# 4                              None                                   None
#
# [5 rows x 34 columns]

# %% [markdown]
# we can save the df in our local for further analysis

# %%
path = '/media/flor/ce9d3b3b-3afb-4b6d-a765-a6c5eeadffe0/flor/Pandemov/challenge/CMU/mapa/data/'
outdir = path + 'github/'

try:
    os.mkdir(outdir)
except:
    pass

df_outer.to_csv(outdir+'oh.csv')
